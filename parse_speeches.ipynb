# %%
import data_processing_utils
import importlib
importlib.reload(data_processing_utils)
# Out:
# <module 'data_processing_utils' from 'C:\\Users\\MainUser\\project\\cs224w_cb_graph\\data_processing_utils.py'>

# %%
#author_name = "m:miran-stephen-i" #"j:jefferson-philip-n" #"p:powell-jerome-h"
# "w:williams-john-c"
# "w:williams-john-c"
# "b:bowman-michelle-w"
author_name = "c:clarida-richard-h" #"e:evans-charles-l" #"m:mester-loretta-j" #"d:daly-mary-c"#h:harker-patrick-t"#b:brainard-lael"#g:goolsbee-austan-d"#s:schmid-jeffrey-r" #"c:collins-susan-m"#p:paulson-anna-l" #"b:bostic-raphael-w"#k:kashkari-neel-t" #"m:miran-stephen-i"
data = data_processing_utils.query_fed_prints_by_author(author_name)
pdf_links = data_processing_utils.retrieve_remaining_ids(author_name, data)
author_short_name = data_processing_utils.get_author_short_name(author_name)
data_processing_utils.pdfs_to_json(pdf_links, f"text_data/{author_short_name}.json")
# Out:
# 46
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20190328a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20190517a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20190222a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20190110a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/clarida20210108a.htm', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20201014a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20190411a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20200521a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20190503a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20200831a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20190605a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/clarida20210414a.htm', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20211108a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20201116a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20200616a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'http://papers.nber.org/papers/w6254.pdf', 'fileformat': 'application/pdf'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20190926a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20191018a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20200225a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20191112a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20181025a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20211130a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20211012a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20200221a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/clarida20210325a.htm', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20211119a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20190228a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/clarida20210224a.htm', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20190409.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/clarida20210517a.htm', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20191001a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20191101a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20191114a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/clarida20210512a.htm', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/econres/ifdp/files/ifdp1244.pdf', 'fileformat': 'application/pdf'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20190701a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20190520a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20181127a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20190513a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/clarida20190530a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# 40
# 34
# Processing PDFs: 100%|██████████| 34/34 [00:29<00:00,  1.17it/s]
# Saved 34 entries → text_data/clarida.json
