# %%
import json

import data_processing_utils
import importlib
importlib.reload(data_processing_utils)
# Out:
# <module 'data_processing_utils' from 'C:\\Users\\MainUser\\project\\cs224w_cb_graph\\data_processing_utils.py'>

# %%
import json

with open(r"info_folder\author_maps.json", "r", encoding="utf-8") as f:
    author_map = json.load(f)

# %%
for row in author_map:
    author_name = row["author_key"]
    data = data_processing_utils.query_fed_prints_by_author(author_name)
    pdf_links = data_processing_utils.retrieve_remaining_ids(author_name, data)
    author_short_name = data_processing_utils.get_author_short_name(author_name)
    data_processing_utils.pdfs_to_json(pdf_links, f"text_data/{author_short_name}.json")
# Out:
# 63
# file {'fileurl': 'https://www.newyorkfed.org/newsevents/speeches/2022/log220110', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://libertystreeteconomics.newyorkfed.org/2022/01/how-the-federal-reserves-monetary-policy-implementation-framework-has-evolved/', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2023/lkl230907', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2023/lkl230303', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/newsevents/speeches/2021/log211014', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/medialibrary/media/newsevents/speeches/2021/log211014/all-charts', 'fileformat': 'application/pdf', 'filefunction': 'Figures'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2025/lkl250206', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/newsevents/speeches/2021/log210415', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/medialibrary/media/newsevents/speeches/2021/log210415/2021-04-15-lorie-logan-sifma-figures', 'fileformat': 'application/pdf', 'filefunction': 'Figures'}
# file {'fileurl': 'https://libertystreeteconomics.newyorkfed.org/2022/01/how-the-fed-adjusts-the-fed-funds-rate-within-its-target-range/', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2024/lkl240301', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2023/lkl230706', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2023/lkl231009', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://libertystreeteconomics.newyorkfed.org/2022/01/how-the-feds-overnight-reverse-repo-facility-works/', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2024/lkl241009', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2025/lkl251121', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/newsevents/speeches/2022/log220602', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/newsevents/speeches/2019/log190417', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/medialibrary/media/newsevents/speeches/2019/log190417/log041719', 'fileformat': 'application/pdf', 'filefunction': 'Figures'}
# file {'fileurl': 'https://www.newyorkfed.org/newsevents/speeches/2020/log200715', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/medialibrary/media/newsevents/speeches/2020/log200714/SIFMA%20Speech%20071420.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Figures'}
# file {'fileurl': 'https://www.newyorkfed.org/newsevents/speeches/2021/log210408', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2023/lkl230518', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2024/lkl240718', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2024/lkl240106', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/newsevents/speeches/2020/log201201', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/medialibrary/media/newsevents/speeches/2020/log201201/fig-all-charts.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Figures'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2025/lkl250603', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2022/lkl221004', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/newsevents/speeches/2020/log200414', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2025/lkl250225', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2025/lkl250519'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2025/lkl251031', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/research/swe/2022/swe2203/swe2203a.aspx', 'fileformat': 'text/html', 'filefunction': 'Article'}
# file {'fileurl': 'https://www.dallasfed.org/research/swe/2022/swe2203.aspx', 'fileformat': 'text/html', 'filefunction': 'Complete issue'}
# file {'fileurl': 'https://www.newyorkfed.org/newsevents/speeches/2018/log180504', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/newsevents/speeches/2019/log191104', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/medialibrary/media/newsevents/speeches/2019/log191104/all-figures.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Figures'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2023/lkl231110', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://libertystreeteconomics.newyorkfed.org/2022/04/the-feds-balance-sheet-runoff-the-role-of-levered-nbfis-and-households/', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/newsevents/speeches/2022/log220302', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/medialibrary/media/newsevents/speeches/2022/log220302/all-charts', 'fileformat': 'application/pdf', 'filefunction': 'Figures'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2025/lkl250410', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2025/lkl251030', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2024/lkl241101', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2025/lkl250930', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2024/lkl241113', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2024/lkl241021', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/newsevents/speeches/2021/log210811', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2022/lkl221110', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2025/lkl251008', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://libertystreeteconomics.newyorkfed.org/2022/04/the-feds-balance-sheet-runoff-and-the-on-rrp-facility/', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2023/lkl230523', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2025/lkl250825', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2025/lkl250715', 'fileformat': 'text/html', 'filefunction': 'Full-text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2025/lkl250529', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/newsevents/speeches/2017/log170518', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/medialibrary/media/newsevents/speeches/2017/log170518/log170518', 'fileformat': 'application/pdf', 'filefunction': 'Figures'}
# file {'fileurl': 'https://www.newyorkfed.org/newsevents/speeches/2020/log201023', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/medialibrary/media/newsevents/speeches/2020/log201023/log201023.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Figures'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2023/lkl230214', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://libertystreeteconomics.newyorkfed.org/2022/01/the-feds-latest-tool-a-standing-repo-facility/', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2024/lkl240917', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2024/lkl240405', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2023/lkl230118', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/medialibrary/media/research/staff_reports/sr712.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/newsevents/speeches/2018/log180109', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2025/lkl250925', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2024/lkl240724', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.dallasfed.org/research/economics/2025/0925', 'fileformat': 'text/html', 'filefunction': 'Full text - essay'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2025/lkl250925', 'fileformat': 'text/html', 'filefunction': 'Full text - speech'}
# file {'fileurl': 'https://www.dallasfed.org/news/speeches/logan/2023/lkl230420', 'fileformat': 'text/html', 'filefunction': 'Full text'}
# file {'fileurl': 'https://www.newyorkfed.org/medialibrary/media/research/epr/10v16n2/1010garb.pdf', 'fileformat': 'application/pdf'}
# file {'fileurl': 'https://www.newyorkfed.org/medialibrary/media/research/epr/10v16n2/1010garb.html', 'fileformat': 'text/html'}
# 62
# 6
# Processing PDFs: 100%|██████████| 6/6 [00:08<00:00,  1.44s/it]
# Saved 6 entries → text_data/logan.json
